# %%
import PyPDF2
import re

# %%
pdf_file = "2024-01-inc.pdf"
reader = PyPDF2.PdfReader(pdf_file)

# %%
print(reader.pages[0].extract_text())
pdf_text = reader.pages[0].extract_text()

# %%
regex = r"APROVADO [^0-9]+.{6} (.{3})"
matches = re.findall(regex, pdf_text)

grades = []

for number in matches:
    grades.append(float(number.replace(',','.')))
len(grades)

# %%
import spacy

# %%
nlp = spacy.load("pt_core_news_sm")

# %%
nlp = spacy.blank('pt')

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'morphologizer', 'parser', 'lemmatizer', 'attribute_ruler', 'ner']

# %%
doc = nlp(pdf_text)

for token in doc:
    print(token, "|", token.lemma_, "|", token.pos_)
# Out:
# PRÓ-REITORIA | PRÓ-REITORIA | NOUN
# DE | DE | ADP
# GRADUAÇÃO | GRADUAÇÃO | NOUN
#
#  |
#  | SPACE
# DIRETORIA | DIRETORIA | NOUN
# DE | DE | ADP
# GESTÃO | GESTÃO | PROPN
# ESCOLAR | ESCOLAR | PROPN
#
#  |
#  | SPACE
# RECONHECIDA | RECONHECIDA | NOUN
# PELO | PELO | ADP
# DECRETO | DECRETO | PROPN
# N | N | PROPN
# ° | ° | NOUN
# 30.417 | 30.417 | NUM
# , | , | PUNCT
# PUBLICADO | PUBLICADO | PROPN
# NO | NO | ADP
# D.O.U. | D.O.U. | PROPN
# DE | DE | ADP
#   |   | SPACE
# N | N | NOUN
# ° | ° | PROPN
# 33 | 33 | NUM
#   |   | SPACE
# DE | DE | ADP
# 08 | 08 | NUM
# DE | DE | ADP
# FEVEREIRO | fEVEREIRO | NOUN
# DE | de | ADP
# 1952 | 1952 | NUM
# E | e | CCONJ
#
#  |
#  | SPACE
# RECREDENCIADA | RECREDENCIADA | PROPN
# PELA | PELA | ADP
# PORTARIA | PORTARIA | NOUN
# N | N | PROPN
# ° | ° | NOUN
# 2.145 | 2.145 | NUM
# - | - | PUNCT
# MEC | MEC | PROPN
# , | , | PUNCT
# DE | DE | PROPN
# 12.12.2019 | 12.12.2019 | PROPN
# , | , | PUNCT
# PUBLICADA | PUBLICADA | PROPN
# NO | NO | ADP
# D.O.U. | D.O.U. | PROPN
# N | N | PROPN
# ° | ° | PROPN
# 241 | 241 | NUM
# , | , | PUNCT
# DE | DE | ADP
# 13.12.2019.HISTÓRICO | 13.12.2019.HISTÓRICO | NUM
# ESCOLAR | ESCOLAR | NOUN
# ACUMULADO | ACUMULADO | VERB
#
#  |
#  | SPACE
# EMITIDO | EMITIDO | PROPN
# EM | EM | PROPN
# : | : | PUNCT
# 12/03/2024 | 12/03/2024 | NUM
#
#  |
#  | SPACE
# Nacionalidade | Nacionalidade | PROPN
# Naturalidade | Naturalidade | PROPN
#
#  |
#  | SPACE
# Data | Data | PROPN
# Colação | Colação | PROPN
# Data | Data | PROPN
# EmissãoMãePai | EmissãoMãePai | ADP
#
#  |
#  | SPACE
# MARCIO | MARCIO | PROPN
# GUILHERME | GUILHERME | NOUN
# DE | de | ADP
# FREITAS | FREITAS | PROPN
#
#  |
#  | SPACE
# POLLYANNA | POLLYANNA | PROPN
# PEPEU | PEPEU | PROPN
# DUARTE | DUARTE | PROPN
# DE | DE | PROPN
# FREITASÓrgãoDADOS | FREITASÓrgãoDADOS | NOUN
# CADASTRAIS | CADASTRAIS | NOUN
#
#  |
#  | SPACE
# Data | Data | PROPN
# Nascimento | Nascimento | PROPN
#
#  |
#  | SPACE
# UF | UF | PROPN
#
#  |
#  | SPACE
# Periodo | Periodo | PROPN
# doIngressoCurso | doIngressoCurso | PROPN
# -ModalidadeAluno(a | -ModalidadeAluno(a | PROPN
# ) | ) | PUNCT
#
#  |
#  | SPACE
# CPF | CPF | NOUN
#
#  |
#  | SPACE
# TurnoCódigo | TurnoCódigo | PROPN
# Matriz | Matriz | PROPN
#
#   |
#   | SPACE
# Coeficiente | coeficiente | ADV
# deRendimento | deRendimento | NOUN
#
#  |
#  | SPACE
# 8,30Data | 8,30Data | NUM
# ConclusãoRegistro | ConclusãoRegistro | PROPN
# Acadêmico | Acadêmico | PROPN
#
#  |
#  | SPACE
# 2022.1PE | 2022.1PE | NUM
#
#  |
#  | SPACE
# 3230Carga | 3230Carga | NUM
# HoráriaPE | HoráriaPE | NOUN
#
#  |
#  | SPACE
# DADOS | DADOS | NOUN
# ACADÊMICOS30/09/2004 | ACADÊMICOS30/09/2004 | VERB
# PEDRO | PEDRO | PROPN
# PEPEU | PEPEU | PROPN
# DUARTE | DUARTE | PROPN
# DE | DE | ADP
# FREITAS | FREITAS | PROPN
# 00000844503 | 00000844503 | NUM
#
#  |
#  | SPACE
# 128.261. | 128.261. | NUM
# 524-67 | 524-67 | NUM
# Brasileira | Brasileira | PROPN
# Recife | Recife | PROPN
# 588902 | 588902 | NUM
# MD | MD | PROPN
#
#  |
#  | SPACE
# MANHA | MANHA | PROPN
# - | - | PUNCT
# - | - | PUNCT
# -UF | -UF | PROPN
# Identidade | Identidade | PROPN
#
#  |
#  | SPACE
# 47.A.7 | 47.A.7 | NUM
# M | M | PROPN
# CIÊNCIA | CIÊNCIA | PROPN
# DA | de o | ADP
# COMPUTAÇÃO | COMPUTAÇÃO | PROPN
# - | - | PUNCT
# BACHARELADO | BACHARELADO | NOUN
#
#  |
#  | SPACE
# Reconhecimento | Reconhecimento | PROPN
#   |   | SPACE
# do | de o | ADP
# curso | curso | NOUN
# : | : | PUNCT
#    |    | SPACE
# Portaria | portaria | NOUN
#     |     | SPACE
# Nº | Nº | NOUN
# 602 | 602 | NUM
# , | , | PUNCT
# de | de | ADP
# 18/08/1986 | 18/08/1986 | NUM
# . | . | PUNCT
#   |   | SPACE
# Publicado | Publicar | VERB
#   |   | SPACE
# em | em | ADP
# D.O.U. | D.O.U. | PROPN
#    |    | SPACE
# Nº | Nº | NOUN
# 158 | 158 | NUM
# Seção | Seção | PROPN
#   |   | SPACE
# 1 | 1 | NUM
# pág. | pág. | NOUN
# 12483 | 12483 | NUM
# , | , | PUNCT
#   |   | SPACE
# de | de | ADP
# 20/08/1986 | 20/08/1986 | NUM
# . | . | PUNCT
#
#  |
#  | SPACE
# Renovação | renovação | NOUN
#   |   | SPACE
# de | de | ADP
# Reconhecimento | Reconhecimento | PROPN
#   |   | SPACE
# do | de o | ADP
# curso | curso | NOUN
# : | : | PUNCT
#    |    | SPACE
# Portaria | portaria | NOUN
#     |     | SPACE
# Nº | Nº | NOUN
# 919 | 919 | NUM
# , | , | PUNCT
# de | de | ADP
# 27/12/2018 | 27/12/2018 | NOUN
# . | . | PUNCT
#   |   | SPACE
# Publicado | Publicar | VERB
#   |   | SPACE
# em | em | ADP
# D.O.U. | D.O.U. | PROPN
#    |    | SPACE
# Nº | Nº | NOUN
# 249 | 249 | PROPN
# Seção | Seção | PROPN
#   |   | SPACE
# 1 | 1 | NUM
# pág. | pág. | NOUN
# 225 | 225 | NUM
# , | , | PUNCT
# de | de | ADP
# 28/12/2018 | 28/12/2018 | NUM
# . | . | PUNCT
#
#  |
#  | SPACE
# Observação | Observação | PROPN
# Ano | Ano | PROPN
# Inscrição | Inscrição | PROPN
# SituaçãoENADE | SituaçãoENADE | PROPN
#
#  |
#  | SPACE
# Dispensado | dispensado | NOUN
# Ingressante | Ingressante | PROPN
# 2022 | 2022 | PROPN
# ESTUDANTE | ESTUDANTE | PROPN
# NÃO | NÃO | ADV
# HABILITADO | HABILITADO | PROPN
# EM | EM | ADP
# RAZÃO | RAZÃO | NOUN
# DO | DO | ADP
# CALENDÁRIO | CALENDÁRIO | NOUN
# DO | DO | ADP
# CICLO | CICLO | PROPN
# A | o | DET
# V | V | PROPN
# ALIATIVO | ALIATIVO | PROPN
# - | - | PUNCT
# ART.58 | ART.58 | PROPN
# DA | de o | ADP
# PORTARIA | PORTARIA | NOUN
#
#  |
#  | SPACE
# NORMATIV | NORMATIV | NOUN
# A | a | ADP
# 840 | 840 | NUM
# / | / | PUNCT
# MEC | MEC | PROPN
# . | . | PUNCT
# DE | DE | ADP
# 2018 | 2018 | NUM
# . | . | PUNCT
#
#  |
#  | SPACE
# Tipo | Tipo | PROPN
# Ingresso | Ingresso | PROPN
#   |   | SPACE
# Argumento | Argumento | PROPN
# deClassificação | deClassificação | NOUN
#
#  |
#  | SPACE
# 12/2021 | 12/2021 | NUM
# 608,2000 | 608,2000 | NUM
# VESTIBULARMês | VESTIBULARMês | PROPN
# / | / | PUNCT
# AnoINGRESSO | AnoINGRESSO | PROPN
#
#   |
#   | SPACE
# Disciplina | Disciplina | PROPN
# Situação | Situação | PROPN
# Créditos | Créditos | PROPN
# CH | CH | PROPN
# Nota | Nota | PROPN
#
#  |
#  | SPACE
# DISCIPLINAS | DISCIPLINAS | NOUN
# OBRIGATÓRIAS | OBRIGATÓRIAS | PROPN
# : | : | PUNCT
# P. | p. | NOUN
# Letivo/ | Letivo/r | VERB
#
#  |
#  | SPACE
# Periodo | periodo | NOUN
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# FILOSOFIA | FILOSOFIA | PROPN
# E | e | CCONJ
# CONHECIMENTO | CONHECIMENTO | PROPN
# TECNOLOGICO | TECNOLOGICO | PROPN
# 2022.1 | 2022.1 | NUM
# 9,7 | 9,7 | NUM
# FIL1433 | FIL1433 | PROPN
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# ELETRONICA | ELETRONICA | PROPN
# BASICA | BASICA | PROPN
# 2022.1 | 2022.1 | NUM
# 7,1 | 7,1 | NUM
# FIS1608 | FIS1608r | VERB
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# INTROD | INTROD | PROPN
# A | o | DET
# CIENCIA | CIENCIA | PROPN
# DA | de o | ADP
# COMPUTACAO | COMPUTACAO | PROPN
# 2022.1 | 2022.1 | NUM
# 9,0 | 9,0 | NUM
# INF1038 | INF1038 | VERB
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# PROGRAMACAO | PROGRAMACAO | PROPN
# I | I | PROPN
# 2022.1 | 2022.1 | NUM
# 9,3 | 9,3 | NUM
# INF1141 | INF1141 | PROPN
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# LOGICA | LOGICA | PROPN
# MATEMATICA | MATEMATICA | PROPN
# 2022.1 | 2022.1 | NUM
# 8,5 | 8,5 | NUM
# INF1250 | INF1250 | VERB
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# PORTUGUES | PORTUGUES | PROPN
# INSTRUMENTAL | INSTRUMENTAL | PROPN
# II | II | PROPN
# 2022.1 | 2022.1 | NUM
# 7,2 | 7,2 | NUM
# LET1057 | LET1057 | SYM
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# PROGRAMACAO | PROGRAMACAO | PROPN
# II | II | PROPN
# 2022.2 | 2022.2 | NUM
# 8,9 | 8,9 | NUM
# INF1142 | INF1142 | PROPN
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# INTRODUCAO | INTRODUCAO | PROPN
# A | o | DET
# ROBOTICA | ROBOTICA | PROPN
# 2022.2 | 2022.2 | NUM
# 8,0 | 8,0 | NUM
# INF1408 | INF1408 | NUM
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# CIRCUITOS | CIRCUITOS | PROPN
# DIGITAIS | DIGITAIS | ADJ
# 2022.2 | 2022.2 | NUM
# 8,5 | 8,5 | NUM
# INF1421 | INF1421 | NUM
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# CALCULO | CALCULO | PROPN
# DIFERENCIAL | DIFERENCIAL | PROPN
# E | e | CCONJ
# INTEGRAL | INTEGRAL | PROPN
# I | I | PROPN
# 2022.2 | 2022.2 | NUM
# 7,0 | 7,0 | NUM
# MAT1009 | MAT1009 | PROPN
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# ALGEBRA | ALGEBRA | PROPN
# LINEAR | LINEAR | PROPN
# I | I | PROPN
# 2022.2 | 2022.2 | NUM
# 7,6 | 7,6 | NUM
# MAT1421 | MAT1421 | NUM
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# HUMANIDADE | HUMANIDADE | PROPN
# E | e | CCONJ
# TRANSCENDENCIA | TRANSCENDENCIA | VERB
# 2022.2 | 2022.2 | NUM
# 8,4 | 8,4 | NUM
# TEO1917 | TEO1917 | NOUN
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# PROGRAMACAO | PROGRAMACAO | PROPN
# III | III | PROPN
# 2023.1 | 2023.1 | NUM
# 9,4 | 9,4 | NUM
# INF1143 | INF1143 | VERB
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# LINGUAGENS | LINGUAGENS | PROPN
# FORMAIS | FORMAIS | PROPN
# 2023.1 | 2023.1 | NUM
# 8,6 | 8,6 | NUM
# INF1149 | INF1149 | ADP
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# ESTRUTURA | ESTRUTURA | PROPN
# DE | de | ADP
# DADOS | DADOS | NOUN
# I | I | PROPN
# 2023.1 | 2023.1 | NUM
# 8,6 | 8,6 | NUM
# INF1251 | INF1251 | X
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# ARQ | ARQ | PROPN
# E | e | CCONJ
# ORGAN | ORGAN | PROPN
# DE | DE | ADP
# COMPUTADORES | COMPUTADORES | PROPN
# I | I | PROPN
# 2023.1 | 2023.1 | NUM
# 7,9 | 7,9 | NUM
# INF1422 | INF1422 | PROPN
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# CALCULO | CALCULO | PROPN
# DIFERENCIAL | DIFERENCIAL | PROPN
# E | e | CCONJ
# INTEGRAL | INTEGRAL | PROPN
# II | II | PROPN
# 2023.1 | 2023.1 | NUM
# 8,6 | 8,6 | NUM
# MAT1010 | MAT1010 | NUM
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# HUMANISMO | HUMANISMO | PROPN
# E | e | CCONJ
# CIDADANIA | CIDADANIA | PROPN
# 2023.1 | 2023.1 | NUM
# 10,0 | 10,0 | NUM
# TEO1916 | TEO1916 | ADJ
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# ESTATISTICA | ESTATISTICA | PROPN
# E | e | CCONJ
# PROBABILIDADE | PROBABILIDADE | VERB
# 2023.2 | 2023.2 | NUM
# 8,2 | 8,2 | NUM
# EST1414 | EST1414 | NUM
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# METODOS | METODOS | ADJ
# NUMERICOS | NUMERICOS | NOUN
# 2023.2 | 2023.2 | NUM
# 9,0 | 9,0 | NUM
# INF1043 | INF1043 | ADP
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# COMPILADORES | COMPILADORES | NOUN
# 2023.2 | 2023.2 | NUM
# 9,1 | 9,1 | NUM
# INF1150 | INF1150 | NOUN
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# ESTRUTURA | ESTRUTURA | PROPN
# DE | de | ADP
# DADOS | DADOS | NOUN
# II | II | ADJ
# 2023.2 | 2023.2 | NUM
# 7,5 | 7,5 | NUM
# INF1252 | INF1252 | PROPN
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# ARQ | ARQ | PROPN
# E | e | CCONJ
# ORGAN | ORGAN | PROPN
# DE | DE | ADP
# COMPUTADORES | COMPUTADORES | PROPN
# II | II | ADJ
# 2023.2 | 2023.2 | NUM
# 5,7 | 5,7 | NUM
# INF1423 | INF1423 | NOUN
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# APROVADO | APROVADO | NOUN
# POR | POR | ADP
# MEDIA | MEDIA | PROPN
# COMPUTACAO | COMPUTACAO | PROPN
# GRAFICA | GRAFICA | PROPN
# 2023.2 | 2023.2 | NUM
# 7,5 | 7,5 | NUM
# INF1761 | INF1761 | PROPN
# 60 | 60 | NUM
# 04 | 04 | NUM
#
#  |
#  | SPACE
# FALTA | FALTA | NOUN
#   |   | SPACE
# CURSAR | CURSAR | PROPN
#
#  |
#  | SPACE
# MATRICULADO | MATRICULADO | NOUN
# 2024.1 | 2024.1 | NUM
# BANCO | BANCO | PROPN
# DE | de | ADP
# DADOS | DADOS | NOUN
# I | I | PROPN
# INF1243 | INF1243 | PROPN
# 60 | 60 | NUM
# 04 | 04 | NUM
# 5 | 5 | NUM
#
#  |
#  | SPACE
# MATRICULADO | MATRICULADO | NOUN
# 2024.1 | 2024.1 | NUM
# ENGENHARIA | ENGENHARIA | PROPN
# DE | de | ADP
# SOFTWARE | SOFTWARE | PROPN
# I | I | PROPN
# INF1764 | INF1764 | PROPN
# 60 | 60 | NUM
# 04 | 04 | NUM
# 5 | 5 | NUM
#
#  |
#  | SPACE
# MATRICULADO | MATRICULADO | NOUN
# 2024.1 | 2024.1 | PROPN
# GRAFOS | GRAFOS | PROPN
# INF1247 | INF1247 | ADP
# 60 | 60 | NUM
# 04 | 04 | NUM
# 5 | 5 | NUM
#
#  |
#  | SPACE
# MATRICULADO | MATRICULADO | NOUN
# 2024.1 | 2024.1 | NUM
# PROGRAMACAO | PROGRAMACAO | PROPN
# WEB | WEB | PROPN
# E | E | CCONJ
# MOBILE | MOBILE | PROPN
# INF1144 | INF1144 | PROPN
# 60 | 60 | NUM
# 04 | 04 | NUM
# 5 | 5 | NUM
#
#  |
#  | SPACE
# MATRICULADO | MATRICULADO | NOUN
# 2024.1 | 2024.1 | NUM
# REDES | REDES | PROPN
# DE | DE | ADP
# COMPUTADORES | COMPUTADORES | PROPN
# I | I | PROPN
# INF1638 | INF1638 | PROPN
# 60 | 60 | NUM
# 04 | 04 | NUM
# 5 | 5 | NUM
#
#  |
#  | SPACE
# MATRICULADO | MATRICULADO | NOUN
# 2024.1 | 2024.1 | NUM
# SISTEMAS | SISTEMAS | PROPN
# OPERACIONAIS | OPERACIONAIS | PROPN
# I | I | PROPN
# INF1245 | INF1245 | PROPN
# 60 | 60 | NUM
# 04 | 04 | NUM
# 5 | 5 | NUM
#
#  |
#  | SPACE
# ANALISE | ANALISE | NOUN
# DE | DE | ADP
# ALGORITMOS | ALGORITMOS | PROPN
# INF1248 | INF1248 | ADP
# 60 | 60 | NUM
# 04 | 04 | NUM
# 6 | 6 | NUM
#
#  |
#  | SPACE
# BANCO | BANCO | PROPN
# DE | de | ADP
# DADOS | DADOS | NOUN
# II | ii | ADJ
# INF1244 | INF1244 | PROPN
# 30 | 30 | NUM
# 02 | 02 | NUM
# 6 | 6 | NUM
#
#  |
#  | SPACE
# ENGENHARIA | ENGENHARIA | PROPN
# DE | DE | ADP
# SOFTWARE | SOFTWARE | PROPN
# II | II | PROPN
# INF1765 | INF1765 | VERB
# 60 | 60 | NUM
# 04 | 04 | NUM
# 6 | 6 | NUM
#
#  |
#  | SPACE
# INTELIGENCIA | INTELIGENCIA | PROPN
# ARTIFICIAL | ARTIFICIAL | PROPN
# INF1779 | INF1779 | VERB
# 60 | 60 | NUM
# 04 | 04 | NUM
# 6 | 6 | NUM
#
#  |
#  | SPACE
# PROJETO | PROJETO | NOUN
# DE | DE | ADP
# DESENVOLVIMENTO | DESENVOLVIMENTO | PROPN
# INF1146 | INF1146 | PROPN
# 60 | 60 | NUM
# 04 | 04 | NUM
# 6 | 6 | NUM
#
#  |
#  | SPACE
# REDES | REDES | PROPN
# DE | DE | ADP
# COMPUTADORES | COMPUTADORES | PROPN
# II | II | ADJ
# INF1639 | INF1639 | NOUN
# 60 | 60 | NUM
# 04 | 04 | NUM
# 6 | 6 | NUM
#
#  |
#  | SPACE
# SISTEMAS | SISTEMAS | PROPN
# OPERACIONAIS | OPERACIONAIS | PROPN
# II | II | PROPN
# INF1246 | INF1246 | ADJ
# 30 | 30 | NUM
# 02 | 02 | NUM
# 6 | 6 | NUM
#
#  |
#  | SPACE
# CIENCIA | CIENCIA | NOUN
# DOS | DOS | ADP
# DADOS | DADOS | NOUN
# INF1780 | INF1780 | ADJ
# 60 | 60 | NUM
# 04 | 04 | NUM
# 7 | 7 | NUM
#
#  |
#  | SPACE
# PÁGINA:1/ | PÁGINA:1/ | PROPN
# 2 | 2 | NUM
#   |   | SPACE
# Registro | Registro | PROPN
# Acadêmico | Acadêmico | PROPN
# : | : | PUNCT
#   |   | SPACE
# 00000844503 | 00000844503 | NUM
#   |   | SPACE
# Histórico | Histórico | PROPN
# Escolar | Escolar | PROPN
# do(a | do(a | PROPN
# ) | ) | PUNCT
# Aluno(a | Aluno(a | INTJ
# ): | ): | PUNCT
#   |   | SPACE
# PEDRO | PEDRO | PROPN
# PEPEU | PEPEU | PROPN
# DUARTE | DUARTE | PROPN
# DE | de | ADP
# FREITAS | FREITAS | PROPN

# %%
tokens = [token.text for token in doc]
tokens
